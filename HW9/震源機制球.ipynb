# %%
# 1. 安裝所需的套件 (在 Colab 中加上驚嘆號 ! 來執行終端機指令)
# !pip install obspy -q  # 加上 -q 可以減少安裝時的冗長輸出資訊
# 2. 匯入所需的模組
import matplotlib.pyplot as plt
from obspy.imaging.beachball import beachball
# 3. 定義震源機制參數 [Strike, Dip, Rake]
focal_mechanism = [184, 17, 71]
# 4. 繪製震源機制球
# Colab 會自動在下方顯示 matplotlib 的圖片
fig = beachball(focal_mechanism, size=200, linewidth=2, facecolor='dodgerblue')
# 5. 儲存圖片 (可選)
# 圖片會儲存在 Colab 左側資料夾圖示的「檔案」區塊中
plt.savefig('beachball_sdr.png', dpi=300, bbox_inches='tight')
# 顯示圖片
plt.show()
